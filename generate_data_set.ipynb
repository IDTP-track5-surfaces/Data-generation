# %%
import os
import matplotlib.pyplot as plt
from imageio.v2 import imread

from data_set import *

# %%
# Create warp map for all simulation data
generaet_warp_map(n1=1, n2=1.33)

# %%
# Create deformed image for each reference pattern
for file in os.listdir('reference_patterns'):
    file_name = os.path.splitext(file)[0]
    path = os.path.join('reference_patterns', file)
    image  = imread(path)
    generate_warped_image(image, file_name)
    
plt.imshow(image)
plt.show()
# Out:
# tex1
